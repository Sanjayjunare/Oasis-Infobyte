# %% [markdown]
# # Oasis Infonbyte- Virtual Internship 2023

# %% [markdown]
# # Name : Sanjay Vijay Junare

# %% [markdown]
# # Task 1:-Iris Flower Classification

# %% [markdown]
# Iris flower has three species, setosa, versicolor, and virginica, which differs according to their measurements Now assume that you have the measurements of the iris flowers according to their species, and here your task is to train a machine learning model that can learn from themeasurements of the iris species and classify themAlthough the Scikit-learn library provides a dataset for ins flower classification, you can also download the same dataset from here for the task of iris flower classification with Machine Learning using python

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # Import Data Set

# %%
data=pd.read_csv('/Users/sanjayjunare/Downloads/Iris (1).csv')

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.sample(10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 128  129            6.4           2.8            5.6           2.1
# 27    28            5.2           3.5            1.5           0.2
# 22    23            4.6           3.6            1.0           0.2
# 26    27            5.0           3.4            1.6           0.4
# 115  116            6.4           3.2            5.3           2.3
# 87    88            6.3           2.3            4.4           1.3
# 140  141            6.7           3.1            5.6           2.4
# 11    12            4.8           3.4            1.6           0.2
# 73    74            6.1           2.8            4.7           1.2
# 92    93            5.8           2.6            4.0           1.2
#
#              Species
# 128   Iris-virginica
# 27       Iris-setosa
# 22       Iris-setosa
# 26       Iris-setosa
# 115   Iris-virginica
# 87   Iris-versicolor
# 140   Iris-virginica
# 11       Iris-setosa
# 73   Iris-versicolor
# ...

# %%
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
data.shape
# Out:
# (150, 6)

# %%
data.drop(columns=['Id'],inplace=True)
data.sample(7)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 81             5.5           2.4            3.7           1.0  Iris-versicolor
# 125            7.2           3.2            6.0           1.8   Iris-virginica
# 118            7.7           2.6            6.9           2.3   Iris-virginica
# 33             5.5           4.2            1.4           0.2      Iris-setosa
# 22             4.6           3.6            1.0           0.2      Iris-setosa
# 49             5.0           3.3            1.4           0.2      Iris-setosa
# 10             5.4           3.7            1.5           0.2      Iris-setosa

# %%
data.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# # Preprocessing of Dataset

# %%
data.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# # EDA on Dataset

# %%
plt.figure(figsize=(11,6))
sns.countplot(data=data,x='Species',edgecolor='linen',alpha=1)
print(data['Species'].value_counts())
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
plt.figure(figsize=(8,8))
data['Species'].value_counts().plot(kind='pie',autopct='%.2f')
plt.legend(loc='upper right', fontsize=9)

# %%
plt.figure(figsize = (10,5))
sns.histplot(x=data['PetalLengthCm'])
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='Count'>

# %%
plt.figure(figsize = (12,6))
sns.distplot(x=data['PetalLengthCm'],color='r')
# Out:
# /var/folders/f_/n7n5vs4d0316yjwdzxxdwnjw0000gn/T/ipykernel_916/147852723.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=data['PetalLengthCm'],color='r')
# <Axes: ylabel='Density'>

# %%
plt.figure(figsize = (10,5))
sns.boxplot(x=data['SepalLengthCm'],color='orange')
# Out:
# <Axes: xlabel='SepalLengthCm'>

# %%
plt.figure(figsize = (10,5))
sns.histplot(data['SepalLengthCm'],color='blue',alpha=0.5)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Count'>

# %%
print('Minimum value of Petal Length in cm:',data['SepalLengthCm'].min())
print('Minimum value of Petal Length in cm:',data['SepalWidthCm'].min())
print('Minimum value of Petal Length in cm:',data['PetalLengthCm'].min())
print('Minimum value of Petal Length in cm:',data['PetalWidthCm'].min())
# Out:
# Minimum value of Petal Length in cm: 4.3
# Minimum value of Petal Length in cm: 2.0
# Minimum value of Petal Length in cm: 1.0
# Minimum value of Petal Length in cm: 0.1

# %%
print('Minimum value of Petal Length in cm:',data['SepalLengthCm'].max())
print('Minimum value of Petal Length in cm:',data['SepalWidthCm'].max())
print('Minimum value of Petal Length in cm:',data['PetalLengthCm'].max())
print('Minimum value of Petal Length in cm:',data['PetalWidthCm'].max())
# Out:
# Minimum value of Petal Length in cm: 7.9
# Minimum value of Petal Length in cm: 4.4
# Minimum value of Petal Length in cm: 6.9
# Minimum value of Petal Length in cm: 2.5

# %%
print('Minimum value of Petal Length in cm:',data['SepalLengthCm'].mean())
print('Minimum value of Petal Length in cm:',data['SepalWidthCm'].mean())
print('Minimum value of Petal Length in cm:',data['PetalLengthCm'].mean())
print('Minimum value of Petal Length in cm:',data['PetalWidthCm'].mean())
# Out:
# Minimum value of Petal Length in cm: 5.843333333333334
# Minimum value of Petal Length in cm: 3.0540000000000003
# Minimum value of Petal Length in cm: 3.758666666666666
# Minimum value of Petal Length in cm: 1.1986666666666668

# %%
plt.style.use('fivethirtyeight')
sns.relplot(x='PetalLengthCm',y='PetalWidthCm',hue='Species',data=data)

# %%
plt.figure(figsize = (10,12))
sns.catplot(x='Species',y='PetalWidthCm',data=data)

# %%
sns.catplot(x='Species',y='PetalLengthCm',data=data)

# %%
sns.catplot(x='Species',y='SepalLengthCm',kind='box',data=data)

# %% [markdown]
# # Correlation Matrix

# %% [markdown]
# A correlation matrix is a table showing correlation coefficients between variables. Each cell in the table shows the correlation between two variables. The value Is in the range of -1 to 1. If two variables have high correlation, we can neglect one variable from those two.

# %%
data.corr()
# Out:
# /var/folders/f_/n7n5vs4d0316yjwdzxxdwnjw0000gn/T/ipykernel_916/2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
corr=data.corr()
fig, ax=plt.subplots(figsize=(10,8))
sns.heatmap(corr,annot=True,ax=ax,cmap='summer')
# Out:
# /var/folders/f_/n7n5vs4d0316yjwdzxxdwnjw0000gn/T/ipykernel_916/2342478618.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=data.corr()
# <Axes: >

# %% [markdown]
# # Label Encoder

# %%
from sklearn.preprocessing import LabelEncoder
Le=LabelEncoder()
data['Species']=Le.fit_transform(data['Species'])
data.sample(7)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 102            7.1           3.0            5.9           2.1        2
# 115            6.4           3.2            5.3           2.3        2
# 36             5.5           3.5            1.3           0.2        0
# 145            6.7           3.0            5.2           2.3        2
# 90             5.5           2.6            4.4           1.2        1
# 132            6.4           2.8            5.6           2.2        2
# 74             6.4           2.9            4.3           1.3        1

# %% [markdown]
# # Training of Model

# %%
from sklearn.model_selection import train_test_split
x=data.drop(columns=['Species'])
y=data['Species']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=0)

# %%
from sklearn.svm import SVC
model=SVC()
model.fit(x_train,y_train)
# Out:
# SVC()

# %%
prediction=model.predict(x_test)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,prediction)*100)
# Out:
# 97.36842105263158

# %% [markdown]
# # Detailed classification Report

# %%
from sklearn.metrics import classification_report 
print(classification_report(y_test,prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       1.00      0.94      0.97        16
#            2       0.90      1.00      0.95         9
#
#     accuracy                           0.97        38
#    macro avg       0.97      0.98      0.97        38
# weighted avg       0.98      0.97      0.97        38

# %% [markdown]
# # Thank You
